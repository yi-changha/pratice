# %% [markdown]
# # 8. 막대 그래프 (기본)

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # WIndows 맑은고딕
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False 
# 한글 폰트 사용 시, 마그너스 글자가 깨지는 현상을 해결

# %%
x = [1,2,3]
y = [2,4,8]

# %%
labels = ['강백호', '서태웅', '정대만'] # 이름
values = [190, 187, 184] # 키

plt.bar(labels, values)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(labels, values, color='r')
# Out:
# <BarContainer object of 3 artists>

# %%
colors = ['r','g','b']
plt.bar(labels, values, color=colors, alpha=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(labels, values)
plt.ylim(175, 195)
# Out:
# (175.0, 195.0)

# %%
plt.bar(labels, values, width=0.3)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(labels, values, width=0.3)
plt.xticks(rotation=45) # x 축의 이름 데이터 각도를 45도로 설정
plt.yticks(rotation=-45) # y 축의 이름 데이터 각도를 -45도로 설정
# Out:
# (array([  0.,  50., 100., 150., 200.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
labels = ['강백호', '서태웅', '정대만'] # 이름
values = [190, 187, 184] # 키
ticks=['1번 학생', '2번 학생', '3번 학생']

plt.bar(labels, values)
plt.xticks(labels,ticks, rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x3035d7d970>,
#   <matplotlib.axis.XTick at 0x3031c661c0>,
#   <matplotlib.axis.XTick at 0x3031c61d00>],
#  [Text(0.0, 0, '1번 학생'), Text(1.0, 0, '2번 학생'), Text(2.0, 0, '3번 학생')])
